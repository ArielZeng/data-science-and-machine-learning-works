# %%
# !pip install requests beautifulsoup4 pandas nltk afinn transformers
# Out:
# Requirement already satisfied: requests in d:\users\xyzen\miniconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in d:\users\xyzen\miniconda3\lib\site-packages (4.12.2)
# Requirement already satisfied: pandas in d:\users\xyzen\miniconda3\lib\site-packages (2.1.0)
# Requirement already satisfied: nltk in d:\users\xyzen\miniconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: afinn in d:\users\xyzen\miniconda3\lib\site-packages (0.1)
# Collecting transformers
#   Downloading transformers-4.38.2-py3-none-any.whl (8.5 MB)
#                                               0.0/8.5 MB ? eta -:--:--
#                                               0.1/8.5 MB 1.1 MB/s eta 0:00:08
#      ------                                   1.4/8.5 MB 14.9 MB/s eta 0:00:01
#      ---------------                          3.4/8.5 MB 23.8 MB/s eta 0:00:01
#      -----------------------                  4.9/8.5 MB 26.2 MB/s eta 0:00:01
#      ------------------------------           6.5/8.5 MB 27.8 MB/s eta 0:00:01
#      ---------------------------------------  8.5/8.5 MB 30.4 MB/s eta 0:00:01
#      ---------------------------------------  8.5/8.5 MB 30.4 MB/s eta 0:00:01
#      ---------------------------------------- 8.5/8.5 MB 26.0 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\xyzen\miniconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\xyzen\miniconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\xyzen\miniconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\xyzen\miniconda3\lib\site-packages (from requests) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in d:\users\xyzen\miniconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: numpy>=1.23.2 in d:\users\xyzen\miniconda3\lib\site-packages (from pandas) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\xyzen\miniconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\users\xyzen\miniconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in d:\users\xyzen\miniconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: click in d:\users\xyzen\miniconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in d:\users\xyzen\miniconda3\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\users\xyzen\miniconda3\lib\site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in d:\users\xyzen\miniconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: filelock in d:\users\xyzen\miniconda3\lib\site-packages (from transformers) (3.12.3)
# Collecting huggingface-hub<1.0,>=0.19.3 (from transformers)
#   Downloading huggingface_hub-0.21.4-py3-none-any.whl (346 kB)
#                                               0.0/346.4 kB ? eta -:--:--
#      ------------------------------------- 346.4/346.4 kB 22.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in d:\users\xyzen\miniconda3\lib\site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\users\xyzen\miniconda3\lib\site-packages (from transformers) (6.0.1)
# Collecting tokenizers<0.19,>=0.14 (from transformers)
#   Downloading tokenizers-0.15.2-cp311-none-win_amd64.whl (2.2 MB)
#                                               0.0/2.2 MB ? eta -:--:--
#      ---------------------------              1.5/2.2 MB 48.6 MB/s eta 0:00:01
#      ---------------------------------------- 2.2/2.2 MB 35.2 MB/s eta 0:00:00
# Collecting safetensors>=0.4.1 (from transformers)
#   Downloading safetensors-0.4.2-cp311-none-win_amd64.whl (269 kB)
#                                               0.0/269.6 kB ? eta -:--:--
#      ------------------------------------- 269.6/269.6 kB 16.2 MB/s eta 0:00:00
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.19.3->transformers)
#   Downloading fsspec-2024.3.0-py3-none-any.whl (171 kB)
#                                               0.0/171.9 kB ? eta -:--:--
#      ---------------------------------------- 171.9/171.9 kB ? eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\users\xyzen\miniconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: six>=1.5 in d:\users\xyzen\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: colorama in d:\users\xyzen\miniconda3\lib\site-packages (from tqdm->nltk) (0.4.6)
# Installing collected packages: safetensors, fsspec, huggingface-hub, tokenizers, transformers
# Successfully installed fsspec-2024.3.0 huggingface-hub-0.21.4 safetensors-0.4.2 tokenizers-0.15.2 transformers-4.38.2

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import download
from afinn import Afinn

# %%
#Step1: Collect data
# Initialize variables
titles = []  # to store news titles
page_number = 0  # starting parameter for Bing news pagination
num_articles = 30  # target number of news articles
query = "ChatGPT and Diffusion models".replace(" ", "+")

# Continue scraping while the number of collected titles is less than the target number
while len(titles) < num_articles:
    # Construct the URL, including the logic for pagination
    url = f'https://www.bing.com/news/search?q={query}&form=QBNH&first={page_number}'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all news items on the current page
    news_items = soup.find_all('div', class_='t_s', limit=30)

    # Extract titles from news items
    for item in news_items:
        title = item.find('a', class_='title')
        if title:
            titles.append(title.text)
        if len(titles) >= num_articles:
            break  # Stop if the target number or more is reached

    # Prepare to scrape the next page
    page_number += 10

# Convert the collected titles to a DataFrame
df = pd.DataFrame({'Title': titles})

# Display the contents of the DataFrame
print(df)

# Save to a CSV file, if needed
df.to_csv('chatgpt_diffusion_models_news.csv', index=False)
# Out:
#                                                 Title
# 0   ChatGPT: 5 changes I'd like to see in the near...
# 1   New AI test measures how fast robots can respo...
# 2   ChatGPT rival from Stable Diffusion creators j...
# 3   Why is AI so bad at spelling? Because image ge...
# 4            OpenAI Sora: Everything you need to know
# 5   Artificial intelligence boosts super-resolutio...
# 6   Microsoft’s Copilot AI set to operate locally ...
# 7                       Why is AI so bad at spelling?
# 8   Key Stable Diffusion Researchers Leave Stabili...
# 9   FLock.io raises $6M for decentralized blockcha...
# 10        What is Midjourney AI and how does it work?
# 11  Microsoft’s Copilot AI set to operate locally ...
# 12            The Best Free AI Art Generators, Ranked
# 13  These Horror Stories Prove That AI Could Pose ...
# 14  What is Suno? The viral AI song generator expl...
# 15  AI is coming to the iPhone–and it could change...
# 16  The next phase of AI is here — and it's not lo...
# 17  Sora AI: What is it? How to access video gener...
# 18  New York Times sues Microsoft and ChatGPT make...
# 19  Do shake-ups at 2 high-profile AI companies si...
# 20  Stability AI CEO steps down ‘to fix concentrat...
# 21  AI news and innovations roundup March 2024 : C...
# 22  Ousted Founder of Stability AI Seen Meeting Wi...
# 23  5 things about AI you may have missed today: B...
# 24  Midjourney: Everything we know about the AI im...
# 25  Unicorn A.I. Startups Are Suddenly Dying As Bi...
# 26  Nvidia Reveals Next-Gen Blackwell GPUs, Promis...
# 27  Will AI Help or Hurt Humanity? Tech Employees ...
# 28  Stability AI founder's jokes about Satya Nadel...
# 29  Nvidia Research Gives Generative AI Images And...

# %%
# steo2: Preprocessing
# Ensure the necessary NLTK packages have been downloaded
download('stopwords')
download('wordnet')

# Read the CSV file
file_path = 'chatgpt_diffusion_models_news.csv'
news_df = pd.read_csv(file_path)

# Define a set of stop words and a lemmatizer
stop_words = set(stopwords.words('english'))  # Other languages can be added as needed
lemmer = WordNetLemmatizer()

# Define a text preprocessing function
def preprocess(x):
    x = re.sub(r'[^\w\s]', ' ', x)  # Remove punctuation
    x = re.sub(r'\d+', '', x)  # Remove numbers
    # Convert to lowercase, remove stop words, and lemmatize
    x = [lemmer.lemmatize(w.lower()) for w in x.split() if w.lower() not in stop_words]  
    return ' '.join(x)

# Apply the preprocessing function
news_df['title_clean'] = news_df['Title'].apply(preprocess)

news_df[['Title', 'title_clean']]  # Display titles before and after processing
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\xyzen\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\xyzen\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                                 Title  \
# 0   ChatGPT: 5 changes I'd like to see in the near...
# 1   New AI test measures how fast robots can respo...
# 2   ChatGPT rival from Stable Diffusion creators j...
# 3   Why is AI so bad at spelling? Because image ge...
# 4            OpenAI Sora: Everything you need to know
# 5   Artificial intelligence boosts super-resolutio...
# 6   Microsoft’s Copilot AI set to operate locally ...
# 7                       Why is AI so bad at spelling?
# 8   Key Stable Diffusion Researchers Leave Stabili...
# 9   FLock.io raises $6M for decentralized blockcha...
# 10        What is Midjourney AI and how does it work?
# 11  Microsoft’s Copilot AI set to operate locally ...
# 12            The Best Free AI Art Generators, Ranked
# 13  These Horror Stories Prove That AI Could Pose ...
# 14  What is Suno? The viral AI song generator expl...
# 15  AI is coming to the iPhone–and it could change...
# 16  The next phase of AI is here — and it's not lo...
# 17  Sora AI: What is it? How to access video gener...
# 18  New York Times sues Microsoft and ChatGPT make...
# 19  Do shake-ups at 2 high-profile AI companies si...
# 20  Stability AI CEO steps down ‘to fix concentrat...
# 21  AI news and innovations roundup March 2024 : C...
# 22  Ousted Founder of Stability AI Seen Meeting Wi...
# 23  5 things about AI you may have missed today: B...
# 24  Midjourney: Everything we know about the AI im...
# 25  Unicorn A.I. Startups Are Suddenly Dying As Bi...
# 26  Nvidia Reveals Next-Gen Blackwell GPUs, Promis...
# 27  Will AI Help or Hurt Humanity? Tech Employees ...
# 28  Stability AI founder's jokes about Satya Nadel...
# 29  Nvidia Research Gives Generative AI Images And...
#
#                                           title_clean
# 0                 chatgpt change like see near future
# 1   new ai test measure fast robot respond user co...
# 2   chatgpt rival stable diffusion creator launche...
# 3   ai bad spelling image generator actually readi...
# 4                    openai sora everything need know
# 5   artificial intelligence boost super resolution...
# 6   microsoft copilot ai set operate locally futur...
# 7                                     ai bad spelling
# 8   key stable diffusion researcher leave stabilit...
# 9   flock io raise decentralized blockchain ai tra...
# 10                                 midjourney ai work
# 11  microsoft copilot ai set operate locally futur...
# 12                  best free ai art generator ranked
# 13    horror story prove ai could pose serious threat
# 14    suno viral ai song generator explained use free
# 15           ai coming iphone could change everything
# 16                       next phase ai looking pretty
# 17                     sora ai access video generator
# 18  new york time sue microsoft chatgpt maker open...
# 19      shake ups high profile ai company signal come
# 20   stability ai ceo step fix concentration power ai
# 21  ai news innovation roundup march chatgpt metap...
# 22  ousted founder stability ai seen meeting micro...
# 23  thing ai may missed today bbc mull house ai mo...
# 24           midjourney everything know ai image tool
# 25  unicorn startup suddenly dying big tech domina...
# 26  nvidia reveals next gen blackwell gpus promise...
# 27  ai help hurt humanity tech employee turn art a...
# 28  stability ai founder joke satya nadella influe...
# 29  nvidia research give generative ai image speed...

# %%
# step3
# Initialize AFINN sentiment analyzer, allowing for emoticons
afinn = Afinn(emoticons=True)

# Perform sentiment analysis on each title and store the results in a list
afinn_scores = [afinn.score(text) for text in news_df['title_clean']]  # Use the 'title_clean' column

# Add the list of sentiment scores to the DataFrame as a new column
news_df['afinn_sentiment'] = afinn_scores

# Display titles with their corresponding sentiment scores
print(news_df[['title_clean', 'afinn_sentiment']])
# Out:
#                                           title_clean  afinn_sentiment
# 0                 chatgpt change like see near future              2.0
# 1   new ai test measure fast robot respond user co...              0.0
# 2   chatgpt rival stable diffusion creator launche...              3.0
# 3   ai bad spelling image generator actually readi...             -3.0
# 4                    openai sora everything need know              0.0
# 5   artificial intelligence boost super resolution...              6.0
# 6   microsoft copilot ai set operate locally futur...              0.0
# 7                                     ai bad spelling             -3.0
# 8   key stable diffusion researcher leave stabilit...              1.0
# 9   flock io raise decentralized blockchain ai tra...              0.0
# 10                                 midjourney ai work              0.0
# 11  microsoft copilot ai set operate locally futur...              0.0
# 12                  best free ai art generator ranked              4.0
# 13    horror story prove ai could pose serious threat             -2.0
# 14    suno viral ai song generator explained use free              1.0
# 15           ai coming iphone could change everything              0.0
# 16                       next phase ai looking pretty              1.0
# 17                     sora ai access video generator              0.0
# 18  new york time sue microsoft chatgpt maker open...             -4.0
# 19      shake ups high profile ai company signal come              0.0
# 20   stability ai ceo step fix concentration power ai              0.0
# 21  ai news innovation roundup march chatgpt metap...              1.0
# 22  ousted founder stability ai seen meeting micro...              0.0
# 23  thing ai may missed today bbc mull house ai mo...             -2.0
# 24           midjourney everything know ai image tool              0.0
# 25  unicorn startup suddenly dying big tech domina...             -2.0
# 26  nvidia reveals next gen blackwell gpus promise...              4.0
# 27  ai help hurt humanity tech employee turn art a...              0.0
# 28  stability ai founder joke satya nadella influe...              2.0
# 29  nvidia research give generative ai image speed...              1.0

# %%
# step4
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification
from transformers import TextClassificationPipeline

# Load the pre-trained DistilBERT model and tokenizer
model_name = "distilbert-base-uncased-finetuned-sst-2-english"
tokenizer = DistilBertTokenizer.from_pretrained(model_name)
model = DistilBertForSequenceClassification.from_pretrained(model_name)

# Create a pipeline for performing sentiment analysis
distilbert_pipeline = TextClassificationPipeline(model=model, tokenizer=tokenizer)

# Define a function to get the sentiment score
def sentiment_score_distilbert(text):
    result = distilbert_pipeline(text)[0]
    score = round(result['score'], 4)  # Round to 4 decimal places
    return score

# Define a function to get the sentiment label
def sentiment_label_distilbert(text):
    result = distilbert_pipeline(text)[0]
    label = result['label']
    return label

# Apply these functions to the news titles and add the results to the DataFrame
news_df['distilbert_score'] = news_df['title_clean'].apply(sentiment_score_distilbert)
news_df['distilbert_label'] = news_df['title_clean'].apply(sentiment_label_distilbert)

# View the DataFrame including the sentiment scores and labels
news_df[['title_clean', 'afinn_sentiment', 'distilbert_score', 'distilbert_label']]
# Out:
#                                           title_clean  afinn_sentiment  \
# 0                 chatgpt change like see near future              2.0
# 1   new ai test measure fast robot respond user co...              0.0
# 2   chatgpt rival stable diffusion creator launche...              3.0
# 3   ai bad spelling image generator actually readi...             -3.0
# 4                    openai sora everything need know              0.0
# 5   artificial intelligence boost super resolution...              6.0
# 6   microsoft copilot ai set operate locally futur...              0.0
# 7                                     ai bad spelling             -3.0
# 8   key stable diffusion researcher leave stabilit...              1.0
# 9   flock io raise decentralized blockchain ai tra...              0.0
# 10                                 midjourney ai work              0.0
# 11  microsoft copilot ai set operate locally futur...              0.0
# 12                  best free ai art generator ranked              4.0
# 13    horror story prove ai could pose serious threat             -2.0
# 14    suno viral ai song generator explained use free              1.0
# 15           ai coming iphone could change everything              0.0
# 16                       next phase ai looking pretty              1.0
# 17                     sora ai access video generator              0.0
# 18  new york time sue microsoft chatgpt maker open...             -4.0
# 19      shake ups high profile ai company signal come              0.0
# 20   stability ai ceo step fix concentration power ai              0.0
# 21  ai news innovation roundup march chatgpt metap...              1.0
# 22  ousted founder stability ai seen meeting micro...              0.0
# 23  thing ai may missed today bbc mull house ai mo...             -2.0
# 24           midjourney everything know ai image tool              0.0
# 25  unicorn startup suddenly dying big tech domina...             -2.0
# 26  nvidia reveals next gen blackwell gpus promise...              4.0
# 27  ai help hurt humanity tech employee turn art a...              0.0
# 28  stability ai founder joke satya nadella influe...              2.0
# 29  nvidia research give generative ai image speed...              1.0
#
#     distilbert_score distilbert_label
# 0             0.6954         NEGATIVE
# 1             0.8759         NEGATIVE
# 2             0.9916         NEGATIVE
# 3             0.9996         NEGATIVE
# 4             0.9811         POSITIVE
# 5             0.9973         POSITIVE
# 6             0.9770         NEGATIVE
# 7             0.9997         NEGATIVE
# 8             0.9922         NEGATIVE
# 9             0.9119         NEGATIVE
# 10            0.9870         NEGATIVE
# 11            0.9770         NEGATIVE
# 12            0.9994         POSITIVE
# 13            0.9945         NEGATIVE
# 14            0.9876         NEGATIVE
# 15            0.9879         NEGATIVE
# 16            0.9882         POSITIVE
# 17            0.9535         NEGATIVE
# 18            0.9976         NEGATIVE
# 19            0.9813         POSITIVE
# 20            0.9695         NEGATIVE
# 21            0.9976         NEGATIVE
# 22            0.8617         POSITIVE
# 23            0.9921         NEGATIVE
# 24            0.9777         NEGATIVE
# 25            0.9980         NEGATIVE
# 26            0.9828         POSITIVE
# 27            0.9886         NEGATIVE
# 28            0.6117         NEGATIVE
# 29            0.9980         POSITIVE

# %%
news_df.to_csv('D:/course/CS688/2/sentiment_and_theme_analysis.csv', index=False)
